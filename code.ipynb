# %% [markdown]
# **Assignment #3**
#
#
# ---
#
#
# **Machine Learning and Data Science ‐ ENCS5341**
#
#
# ---
#
#
# **Section 2**
#
#
# ---
#
#
# **Raghad Afaghani - 1192423**
#
# **Logain Abdalrazaq - 1190707**
#
#
# ---

# %% [markdown]
# ***Fetal Health Dataset***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Loading the dataset**

# %%
import pandas as pd

data = pd.read_csv("fetal_health.csv")
data.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %% [markdown]
# **About the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
# ...

# %%
data.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# ...

# %%
import seaborn as sns

sns.countplot(x="fetal_health", data=data, palette=["#FAD02E", "#A3CB38", "#FFDDC1"])
# Out:
# <ipython-input-5-1d5b8262784c>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="fetal_health", data=data, palette=["#FAD02E", "#A3CB38", "#FFDDC1"])
# <Axes: xlabel='fetal_health', ylabel='count'>

# %% [markdown]
# **Model Selection**
#
# 1.Define features (X) and the target (Y).
#
# 2.Apply feature scaling.
#
# 3.Split the data into training and test sets.
#
# 4.Choose a machine learning model.
#
# 5.Fine-tune the model's hyperparameters.

# %%
# Assign features (X) and target (y)
X = data.drop(columns=["fetal_health"])
y = data["fetal_health"]

# Standardize the features and display summary statistics
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X.describe().T
# Out:
#                                                      count          mean  \
# baseline value                                      2126.0  1.069490e-15
# accelerations                                       2126.0 -4.010589e-17
# fetal_movement                                      2126.0 -1.336863e-17
# uterine_contractions                                2126.0 -1.336863e-16
# light_decelerations                                 2126.0 -5.347452e-17
# severe_decelerations                                2126.0  6.684315e-18
# prolongued_decelerations                            2126.0  1.336863e-17
# abnormal_short_term_variability                     2126.0 -7.352747e-17
# mean_value_of_short_term_variability                2126.0  6.684315e-17
# percentage_of_time_with_abnormal_long_term_vari...  2126.0 -5.347452e-17
# mean_value_of_long_term_variability                 2126.0  2.406354e-16
# histogram_width                                     2126.0 -3.007942e-17
# ...

# %%
# Splitting the dataset into training and test sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# **Random Forest**

# %%
# Define parameters to test for the Random Forest model
param_grid = {
'n_estimators': [100, 150, 200, 500, 700, 900],
'max_depth': [4, 6, 8, 12, 14, 16],
}

# Use GridSearchCV to find the best combination of parameters
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

grid_search = GridSearchCV(RandomForestClassifier(), param_grid, cv=5)
grid_search.fit(X_train, y_train)

#Best parameter values
best_params = grid_search.best_params_

#Random Forest model with the best parameters and train it
best_RF_model = RandomForestClassifier(**best_params)
best_RF_model.fit(X_train, y_train)

# Testing
from sklearn.metrics import accuracy_score

predictions = best_RF_model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, mean_squared_error

# Calculate performance metrics
metrics = {
    "Accuracy": accuracy_score(y_test, predictions),
    "Recall": recall_score(y_test, predictions, average="weighted"),
    "Precision": precision_score(y_test, predictions, average="weighted"),
    "F1 Score": f1_score(y_test, predictions, average="micro"),
    "Mean Squared Error": mean_squared_error(y_test, predictions)
}

# Display Random Forest results
print("********* Random Forest Results *********")
for metric, value in metrics.items():
    print(f"{metric:<20}: {value:.4f}")
# Out:
# ********* Random Forest Results *********
# Accuracy            : 0.9420
# Recall              : 0.9420
# Precision           : 0.9411
# F1 Score            : 0.9420
# Mean Squared Error  : 0.0815

# %% [markdown]
# **Logistic Regression**

# %%
import warnings
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix

# Logistic Regression model
logreg = LogisticRegression()

# Hyperparameter grid for tuning
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Regularization strength
    'penalty': ['l1', 'l2'],              # Type of penalty
    'solver': ['liblinear', 'saga']       # Solvers that support l1 penalty
}

# GridSearchCV object
grid_search = GridSearchCV(logreg, param_grid, cv=5, scoring='accuracy')

warnings.filterwarnings("ignore", category=UserWarning)

# Fit the model to the training data
grid_search.fit(X_train, y_train)

# Print the best parameters found by GridSearchCV
print("Best parameters: ", grid_search.best_params_)
# Out:
# Best parameters:  {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
import warnings
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, mean_squared_error

# Predictions using the best hyperparameters
best_model = grid_search.best_estimator_
predictions = best_model.predict(X_test)

# Calculate performance metrics
metrics = {
    "Accuracy": accuracy_score(y_test, predictions),
    "Recall": recall_score(y_test, predictions, average="weighted"),
    "Precision": precision_score(y_test, predictions, average="weighted"),
    "F1 Score": f1_score(y_test, predictions, average="micro"),
    "Mean Squared Error": mean_squared_error(y_test, predictions)
}

# Display Logistic Regression results
print("********* Logistic Regression Results *********")
for metric, value in metrics.items():
    print(f"{metric:<20}: {value:.4f}")
# Out:
# ********* Logistic Regression Results *********
# Accuracy            : 0.8824
# Recall              : 0.8824
# Precision           : 0.8803
# F1 Score            : 0.8824
# Mean Squared Error  : 0.1505

# %%
pip install --upgrade scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 28.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %% [markdown]
# **K-nearest neighbor**

# %%
import warnings
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

warnings.filterwarnings("ignore", category=UserWarning)

# KNN with k=1
knn_1 = KNeighborsClassifier(n_neighbors=1)
knn_1.fit(X_train, y_train)
y_pred_1 = knn_1.predict(X_test)

# KNN with k=3
knn_3 = KNeighborsClassifier(n_neighbors=3)
knn_3.fit(X_train, y_train)
y_pred_3 = knn_3.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, mean_squared_error

# KNN with k=1
y_pred_1 = knn_1.predict(X_test)

# KNN with k=3
y_pred_3 = knn_3.predict(X_test)

#Performance metrics for KNN with k=1
metrics_k1 = {
    "Accuracy (k=1)": accuracy_score(y_test, y_pred_1),
    "Recall (k=1)": recall_score(y_test, y_pred_1, average="weighted"),
    "Precision (k=1)": precision_score(y_test, y_pred_1, average="weighted"),
    "F1 Score (k=1)": f1_score(y_test, y_pred_1, average="micro"),
    "Mean Squared Error (k=1)": mean_squared_error(y_test, y_pred_1)
}

#Performance metrics for KNN with k=3
metrics_k3 = {
    "Accuracy (k=3)": accuracy_score(y_test, y_pred_3),
    "Recall (k=3)": recall_score(y_test, y_pred_3, average="weighted"),
    "Precision (k=3)": precision_score(y_test, y_pred_3, average="weighted"),
    "F1 Score (k=3)": f1_score(y_test, y_pred_3, average="micro"),
    "Mean Squared Error (k=3)": mean_squared_error(y_test, y_pred_3)
}

# Display K-nearest neighbors results for k=1
print("********* K-Nearest Neighbors Results (k=1) *********")
for metric, value in metrics_k1.items():
    print(f"{metric:<30}: {value:.4f}")

# Display K-nearest neighbors results for k=3
print("\n********* K-Nearest Neighbors Results (k=3) *********")
for metric, value in metrics_k3.items():
    print(f"{metric:<30}: {value:.4f}")
# Out:
# ********* K-Nearest Neighbors Results (k=1) *********
# Accuracy (k=1)                : 0.8981
# Recall (k=1)                  : 0.8981
# Precision (k=1)               : 0.8953
# F1 Score (k=1)                : 0.8981
# Mean Squared Error (k=1)      : 0.1207
#
# ********* K-Nearest Neighbors Results (k=3) *********
# Accuracy (k=3)                : 0.9091
# Recall (k=3)                  : 0.9091
# Precision (k=3)               : 0.9073
# F1 Score (k=3)                : 0.9091
# Mean Squared Error (k=3)      : 0.1285

# %% [markdown]
# **Performance analysis for best model which is Random Forest**
#
#
#
# ---

# %%
# Actual labels in 'y_test'

# DataFrame to compare actual and predicted values
results_df = pd.DataFrame({'Actual': y_test, 'Predicted': predictions})

# Adding Column to flag misclassified instances
results_df['Misclassified'] = results_df['Actual'] != results_df['Predicted']

# Merge the misclassified data with the original features
misclassified_full = X_test.join(results_df[results_df['Misclassified']], how='inner')

import matplotlib.pyplot as plt
import seaborn as sns

# 4 images in the row
cols = 4
rows = len(X_test.columns) // cols + (len(X_test.columns) % cols > 0)

plt.figure(figsize=(20, 5 * rows))

for i, feature in enumerate(X_test.columns):
    plt.subplot(rows, cols, i + 1)
    sns.histplot(correctly_classified[feature], color="green", label="Correctly Classified", kde=True)
    sns.histplot(misclassified_full[feature], color="red", label="Misclassified", kde=True)
    plt.title(f'{feature} Distribution')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# * Correctly classified instances for most features show a strong central tendency, with the majority having values around the mode. This implies that the model is effective in identifying the common patterns within the majority of the data.
#
# * Misclassified instances are fewer in number (as seen by the lower red bars), which is expected in a well-performing model.
